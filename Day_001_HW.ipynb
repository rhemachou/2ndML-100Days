# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error():
    """
   Bank Personal Loan Modeling 
1. 你選的這組資料為何重要:   I work for a bank, this is a good starting project.
2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集):  It is from a bank masked data.
3. 蒐集而來的資料型態為何:  CSV format
4. 這組資料想解決的問題如何評估:  It tries to predict from customer income and demographics.

作業2：
想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
   提升業績 表示收入與盈餘提高。時間效益更高，更快載到客人，中間等待時間更短。
   分析某時間某地點有沒有集中叫車的趨勢，能否連成最佳通勤路線
2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
     費率表結合Google Map data結合時間
3. 蒐集而來的資料型態為何:  交易資料表
4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證):  最佳化路線 vs. 隨機路線的收益營收平均與標準差
    """

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-5eedadaa368e> in <module>
#       1 # 執行 Function, 確認有沒有正常執行
# ----> 2 MSE = mean_squared_error(y, y_hat)
#       3 MAE = mean_absolute_error(y, y_hat)
#       4 print("The Mean squared error is %.3f" % (MSE))
#       5 print("The Mean absolute error is %.3f" % (MAE))
#
# TypeError: mean_squared_error() takes 0 positional arguments but 2 were given
